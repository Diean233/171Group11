# %% [markdown]
# # Long Short Term Memory (LSTM) Model
#
# LSTMs are variations of recurrent neural networks.
#
# *Acknowledgments:* Presented with [help](https://www.simplilearn.com/tutorials/machine-learning-tutorial/stock-price-prediction-using-machine-learning) and [more help](https://github.com/kshitij-raj/Stock-Price-Prediction-LSTM).

# %%
## Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.callbacks import  EarlyStopping
from keras import optimizers
from tensorflow import keras

# %%
## Load, preprocess data
df = pd.read_csv('./TSLA.csv')

# We will train on closing prices
df = df.reset_index()['Close']
sc = MinMaxScaler()
df = sc.fit_transform(np.array(df).reshape(-1,1))
train, test = train_test_split(df, test_size = 0.2, shuffle = False)

# Modify training, testing data with timesteps
def create_timeseries(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        a = data[i:(i + time_step), 0]
        X.append(a)
        y.append(data[(i + time_step), 0])
    return np.array(X), np.array(y)

time_step = 60
X_train, y_train = create_timeseries(train, time_step)
X_test, y_test = create_timeseries(test, time_step)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
## Build and fit LSTM

model = Sequential()

model.add(LSTM(50, return_sequences = True, input_shape = (time_step, 1)))
model.add(LSTM(50, return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))

# %%
optimizer = keras.optimizers.Adam(learning_rate = 0.01)

model.compile(loss = 'mean_squared_error', optimizer = optimizer)

early_stop = EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'auto', verbose = 1)

history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 100,
                    batch_size = 64, verbose = 1, callbacks = [early_stop])
# Out:
# Epoch 1/100
# 35/35 [==============================] - 13s 193ms/step - loss: 0.0021 - val_loss: 0.2379
# Epoch 2/100
# 35/35 [==============================] - 5s 143ms/step - loss: 2.4241e-04 - val_loss: 0.0767
# Epoch 3/100
# 35/35 [==============================] - 4s 117ms/step - loss: 2.6021e-05 - val_loss: 0.0699
# Epoch 4/100
# 35/35 [==============================] - 4s 102ms/step - loss: 1.9400e-05 - val_loss: 0.0655
# Epoch 5/100
# 35/35 [==============================] - 4s 105ms/step - loss: 1.5554e-05 - val_loss: 0.0645
# Epoch 6/100
# 35/35 [==============================] - 4s 104ms/step - loss: 1.3413e-05 - val_loss: 0.0634
# Epoch 7/100
# 35/35 [==============================] - 4s 108ms/step - loss: 1.4148e-05 - val_loss: 0.0603
# Epoch 8/100
# 35/35 [==============================] - 4s 115ms/step - loss: 1.3005e-05 - val_loss: 0.0579
# Epoch 9/100
# 35/35 [==============================] - 5s 134ms/step - loss: 1.1962e-05 - val_loss: 0.0596
# Epoch 10/100
# 35/35 [==============================] - 4s 106ms/step - loss: 1.3027e-05 - val_loss: 0.0548
# Epoch 11/100
# 35/35 [==============================] - 4s 113ms/step - loss: 1.2314e-05 - val_loss: 0.0516
# Epoch 12/100
# 35/35 [==============================] - 4s 124ms/step - loss: 1.2770e-05 - val_loss: 0.0515
# Epoch 13/100
# 35/35 [==============================] - 4s 118ms/step - loss: 1.4277e-05 - val_loss: 0.0507
# Epoch 14/100
# 35/35 [==============================] - 4s 104ms/step - loss: 1.0118e-05 - val_loss: 0.0500
# Epoch 15/100
# 35/35 [==============================] - 5s 152ms/step - loss: 1.0565e-05 - val_loss: 0.0510
# Epoch 16/100
# 35/35 [==============================] - 6s 164ms/step - loss: 3.8251e-06 - val_loss: 0.0175
# Epoch 71/100
# 35/35 [==============================] - 5s 141ms/step - loss: 3.9960e-06 - val_loss: 0.0200
# Epoch 72/100
# 35/35 [==============================] - 5s 149ms/step - loss: 6.4218e-06 - val_loss: 0.0211
# Epoch 73/100
# 35/35 [==============================] - 7s 199ms/step - loss: 5.6252e-06 - val_loss: 0.0196
# Epoch 74/100
# 35/35 [==============================] - 6s 176ms/step - loss: 4.7977e-06 - val_loss: 0.0165
# Epoch 00074: early stopping

# %%
## Analyze Model Loss
plt.figure(figsize = (15, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('LSTM Model Loss')
plt.ylabel('Loss')
plt.xlabel("Epochs")
plt.legend(['loss', 'val_loss'], loc='upper right')
plt.show()

# %% [markdown]
# Here, ``loss`` is the MSE for our training data, and ``val_loss`` is the MSE for our cross-validation data.

# %%
##Predict
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

# Invert transformation to get stock prices
train_pred = sc.inverse_transform(train_pred)
test_pred = sc.inverse_transform(test_pred)

# %%
## Observed v. Predicted Results
# Shift train prediction for plotting
train_pred_plot = np.empty_like(df)
train_pred_plot[:, :] = np.nan
train_pred_plot[time_step: len(train_pred) + time_step, :] = train_pred

# Shift test prediction for plotting
test_pred_plot = np.empty_like(df)
test_pred_plot[:, :] = np.nan
test_pred_plot[len(train_pred) + (time_step * 2) + 1: len(df) -1, :] = test_pred

plt.figure(figsize = (15, 10))
plt.plot(sc.inverse_transform(df), color = 'gray', linewidth = 1, label = 'Actual')
plt.plot(train_pred_plot, linewidth = 1, color = 'red', label = 'Train Predict')
plt.plot(test_pred_plot, linewidth = 1, color = 'green', label = 'Test Predict')
plt.legend()
plt.xlabel('Time')
plt.ylabel('TSLA Stock Price (USD)')
plt.title('TSLA Stock Price Prediction, LSTM')
plt.show()

# %% [markdown]
# ## Hyperparameter Turning using Bayesian Optimization
# References:
# - [Stack Exchange](https://datascience.stackexchange.com/questions/73605/opinions-on-an-lstm-hyper-parameter-tuning-process-i-am-using)
# - [Tutorial One](https://github.com/fmfn/BayesianOptimization)
# - [Tutorial Two](https://pythonprogramming.net/keras-tuner-optimizing-neural-network-tutorial/)

# %%
from keras_tuner.tuners import BayesianOptimization

def build_model(hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('units', min_value=8,
                               max_value=64, step=8),
                   return_sequences=True, input_shape = (time_step,1)))
    
    model.add(LSTM(units=hp.Int('units', min_value=8, max_value=64, step=8),
                   return_sequences=True))
    
    model.add(LSTM(units=hp.Int('units', min_value=8, max_value=64, step=8)))
    
    model.add(Dense(1))
    model.compile(loss = 'mean_squared_error', metrics = ['mse'], 
                  optimizer = keras.optimizers.Adam(
                      hp.Choice('learning_rate', values = [0.01,0.001,0.0001])))
    return model

bayesian_opt_tuner = BayesianOptimization(
    build_model,
    objective='mse',
    max_trials=20,
    executions_per_trial=1, overwrite=True,
    project_name='LSTM_Tesla_stock_price'
)

# %%
# takes ~30 minutes
bayesian_opt_tuner.search(X_train, y_train, epochs = 100,
                         validation_data=(X_test, y_test),
                         verbose = 1, batch_size = 64, 
                         callbacks = [early_stop]
                         )
# Out:
# Trial 20 Complete [00h 00m 38s]
# mse: 8.346633876499254e-06
#
# Best mse So Far: 2.19741627915937e-06
# Total elapsed time: 03h 04m 56s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit

# %%
best_hp = bayesian_opt_tuner.get_best_hyperparameters()[0]
print(best_hp.values)
# Out:
# {'units': 16, 'learning_rate': 0.01}

# %%
bayesian_opt_tuner.results_summary()
# Out:
# Results summary
# Results in ./LSTM_Tesla_stock_price
# Showing 10 best trials
# Objective(name='mse', direction='min')
# Trial summary
# Hyperparameters:
# units: 16
# learning_rate: 0.01
# Score: 2.19741627915937e-06
# Trial summary
# Hyperparameters:
# units: 8
# learning_rate: 0.01
# Score: 2.3702496037003584e-06
# Trial summary
# Hyperparameters:
# units: 16
# learning_rate: 0.01
# Score: 2.4113699055305915e-06
# Trial summary
# Hyperparameters:
# units: 16
# learning_rate: 0.01
# Score: 2.424933200018131e-06
# Trial summary
# Hyperparameters:
# units: 8
# learning_rate: 0.01
# Score: 2.4325686354131903e-06
# Trial summary
# Hyperparameters:
# units: 8
# learning_rate: 0.01
# Score: 2.5609751901356503e-06
# Trial summary
# Hyperparameters:
# units: 8
# learning_rate: 0.01
# Score: 2.6838877147383755e-06
# Trial summary
# Hyperparameters:
# units: 16
# learning_rate: 0.01
# Score: 2.7169344321009703e-06
# Trial summary
# Hyperparameters:
# units: 16
# learning_rate: 0.01
# Score: 2.8502754503278993e-06
# Trial summary
# Hyperparameters:
# units: 16
# learning_rate: 0.01
# Score: 3.0185424293449614e-06

# %% [markdown]
# ## Rebuild model using tuned hyperparameters

# %%
model = build_model(best_hp)

early_stop = EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'auto', verbose = 1)

history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 100,
                    batch_size = 64, verbose = 1, callbacks = [early_stop])
# Out:
# Epoch 1/100
# 35/35 [==============================] - 11s 128ms/step - loss: 7.0008e-04 - mse: 7.0008e-04 - val_loss: 0.1074 - val_mse: 0.1074
# Epoch 2/100
# 35/35 [==============================] - 3s 82ms/step - loss: 2.9881e-05 - mse: 2.9881e-05 - val_loss: 0.0798 - val_mse: 0.0798
# Epoch 3/100
# 35/35 [==============================] - 3s 80ms/step - loss: 1.3047e-05 - mse: 1.3047e-05 - val_loss: 0.0773 - val_mse: 0.0773
# Epoch 4/100
# 35/35 [==============================] - 3s 79ms/step - loss: 1.3377e-05 - mse: 1.3377e-05 - val_loss: 0.0770 - val_mse: 0.0770
# Epoch 5/100
# 35/35 [==============================] - 3s 77ms/step - loss: 1.1611e-05 - mse: 1.1611e-05 - val_loss: 0.0763 - val_mse: 0.0763
# Epoch 6/100
# 35/35 [==============================] - 3s 82ms/step - loss: 1.2443e-05 - mse: 1.2443e-05 - val_loss: 0.0715 - val_mse: 0.0715
# Epoch 7/100
# 35/35 [==============================] - 3s 93ms/step - loss: 1.1378e-05 - mse: 1.1378e-05 - val_loss: 0.0696 - val_mse: 0.0696
# Epoch 8/100
# 35/35 [==============================] - 3s 77ms/step - loss: 1.0259e-05 - mse: 1.0259e-05 - val_loss: 0.0664 - val_mse: 0.0664
# Epoch 9/100
# 35/35 [==============================] - 3s 83ms/step - loss: 1.1672e-05 - mse: 1.1672e-05 - val_loss: 0.0673 - val_mse: 0.0673
# Epoch 10/100
# 35/35 [==============================] - 3s 79ms/step - loss: 1.3567e-05 - mse: 1.3567e-05 - val_loss: 0.0663 - val_mse: 0.0663
# Epoch 11/100
# 35/35 [==============================] - 3s 76ms/step - loss: 1.1285e-05 - mse: 1.1285e-05 - val_loss: 0.0633 - val_mse: 0.0633
# Epoch 12/100
# 35/35 [==============================] - 3s 77ms/step - loss: 9.6706e-06 - mse: 9.6706e-06 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 13/100
# 35/35 [==============================] - 3s 79ms/step - loss: 1.0674e-05 - mse: 1.0674e-05 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 14/100
# 35/35 [==============================] - 3s 78ms/step - loss: 1.0171e-05 - mse: 1.0171e-05 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 15/100
# 35/35 [==============================] - 3s 78ms/step - loss: 8.6821e-06 - mse: 8.6821e-06 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 16/100
# 35/35 [==============================] - 3s 80ms/step - loss: 8.8607e-06 - mse: 8.8607e-06 - val_loss: 0.0551 - val_mse: 0.0551
# Epoch 17/100
# 35/35 [==============================] - 3s 80ms/step - loss: 9.8302e-06 - mse: 9.8302e-06 - val_loss: 0.0538 - val_mse: 0.0538
# Epoch 18/100
# 35/35 [==============================] - 3s 78ms/step - loss: 8.6899e-06 - mse: 8.6899e-06 - val_loss: 0.0520 - val_mse: 0.0520
# Epoch 19/100
# 35/35 [==============================] - 3s 76ms/step - loss: 1.1721e-05 - mse: 1.1721e-05 - val_loss: 0.0564 - val_mse: 0.0564
# Epoch 20/100
# 35/35 [==============================] - 3s 88ms/step - loss: 8.1273e-06 - mse: 8.1273e-06 - val_loss: 0.0546 - val_mse: 0.0546
# Epoch 21/100
# 35/35 [==============================] - 3s 93ms/step - loss: 7.6105e-06 - mse: 7.6105e-06 - val_loss: 0.0501 - val_mse: 0.0501
# Epoch 22/100
# 35/35 [==============================] - 3s 89ms/step - loss: 8.5446e-06 - mse: 8.5446e-06 - val_loss: 0.0505 - val_mse: 0.0505
# Epoch 23/100
# 35/35 [==============================] - 3s 90ms/step - loss: 1.0121e-05 - mse: 1.0121e-05 - val_loss: 0.0468 - val_mse: 0.0468
# Epoch 24/100
# 35/35 [==============================] - 3s 95ms/step - loss: 8.2134e-06 - mse: 8.2134e-06 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 25/100
# 35/35 [==============================] - 3s 95ms/step - loss: 8.2775e-06 - mse: 8.2775e-06 - val_loss: 0.0482 - val_mse: 0.0482
# Epoch 26/100
# 35/35 [==============================] - 4s 104ms/step - loss: 6.3013e-06 - mse: 6.3013e-06 - val_loss: 0.0454 - val_mse: 0.0454
# Epoch 27/100
# 35/35 [==============================] - 3s 96ms/step - loss: 6.9577e-06 - mse: 6.9577e-06 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 28/100
# 35/35 [==============================] - 3s 96ms/step - loss: 5.9419e-06 - mse: 5.9419e-06 - val_loss: 0.0445 - val_mse: 0.0445
# Epoch 29/100
# 35/35 [==============================] - 3s 89ms/step - loss: 1.1141e-05 - mse: 1.1141e-05 - val_loss: 0.0412 - val_mse: 0.0412
# Epoch 30/100
# 35/35 [==============================] - 3s 92ms/step - loss: 5.5879e-06 - mse: 5.5879e-06 - val_loss: 0.0407 - val_mse: 0.0407
# Epoch 31/100
# 35/35 [==============================] - 3s 97ms/step - loss: 7.0087e-06 - mse: 7.0087e-06 - val_loss: 0.0393 - val_mse: 0.0393
# Epoch 32/100
# 35/35 [==============================] - 4s 101ms/step - loss: 6.0342e-06 - mse: 6.0342e-06 - val_loss: 0.0356 - val_mse: 0.0356
# Epoch 33/100
# 35/35 [==============================] - 3s 89ms/step - loss: 9.0862e-06 - mse: 9.0862e-06 - val_loss: 0.0394 - val_mse: 0.0394
# Epoch 34/100
# 35/35 [==============================] - 3s 94ms/step - loss: 6.4770e-06 - mse: 6.4770e-06 - val_loss: 0.0420 - val_mse: 0.0420
# Epoch 35/100
# 35/35 [==============================] - 3s 79ms/step - loss: 7.3633e-06 - mse: 7.3633e-06 - val_loss: 0.0399 - val_mse: 0.0399
# Epoch 36/100
# 35/35 [==============================] - 3s 82ms/step - loss: 5.1094e-06 - mse: 5.1094e-06 - val_loss: 0.0335 - val_mse: 0.0335
# Epoch 37/100
# 35/35 [==============================] - 3s 84ms/step - loss: 5.7948e-06 - mse: 5.7948e-06 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 38/100
# 35/35 [==============================] - 3s 90ms/step - loss: 6.5990e-06 - mse: 6.5990e-06 - val_loss: 0.0337 - val_mse: 0.0337
# Epoch 39/100
# 35/35 [==============================] - 3s 92ms/step - loss: 6.4991e-06 - mse: 6.4991e-06 - val_loss: 0.0335 - val_mse: 0.0335
# Epoch 40/100
# 35/35 [==============================] - 3s 88ms/step - loss: 5.0571e-06 - mse: 5.0571e-06 - val_loss: 0.0346 - val_mse: 0.0346
# Epoch 41/100
# 35/35 [==============================] - 4s 129ms/step - loss: 5.6556e-06 - mse: 5.6556e-06 - val_loss: 0.0330 - val_mse: 0.0330
# Epoch 42/100
# 35/35 [==============================] - 3s 91ms/step - loss: 4.4820e-06 - mse: 4.4820e-06 - val_loss: 0.0311 - val_mse: 0.0311
# Epoch 43/100
# 35/35 [==============================] - 3s 95ms/step - loss: 5.7688e-06 - mse: 5.7688e-06 - val_loss: 0.0283 - val_mse: 0.0283
# Epoch 44/100
# 35/35 [==============================] - 3s 79ms/step - loss: 4.2652e-06 - mse: 4.2652e-06 - val_loss: 0.0296 - val_mse: 0.0296
# Epoch 45/100
# 35/35 [==============================] - 3s 89ms/step - loss: 4.0928e-06 - mse: 4.0928e-06 - val_loss: 0.0263 - val_mse: 0.0263
# Epoch 46/100
# 35/35 [==============================] - 3s 77ms/step - loss: 4.6115e-06 - mse: 4.6115e-06 - val_loss: 0.0240 - val_mse: 0.0240
# Epoch 47/100
# 35/35 [==============================] - 3s 89ms/step - loss: 4.8957e-06 - mse: 4.8957e-06 - val_loss: 0.0208 - val_mse: 0.0208
# Epoch 48/100
# 35/35 [==============================] - 3s 87ms/step - loss: 5.1730e-06 - mse: 5.1730e-06 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 49/100
# 35/35 [==============================] - 3s 85ms/step - loss: 4.1527e-06 - mse: 4.1527e-06 - val_loss: 0.0229 - val_mse: 0.0229
# Epoch 50/100
# 35/35 [==============================] - 3s 83ms/step - loss: 6.0224e-06 - mse: 6.0224e-06 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 51/100
# 35/35 [==============================] - 3s 76ms/step - loss: 6.1059e-06 - mse: 6.1059e-06 - val_loss: 0.0237 - val_mse: 0.0237
# Epoch 52/100
# 35/35 [==============================] - 3s 77ms/step - loss: 4.2674e-06 - mse: 4.2674e-06 - val_loss: 0.0214 - val_mse: 0.0214
# Epoch 53/100
# 35/35 [==============================] - 3s 79ms/step - loss: 4.6566e-06 - mse: 4.6566e-06 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 54/100
# 35/35 [==============================] - 3s 89ms/step - loss: 4.0357e-06 - mse: 4.0357e-06 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 55/100
# 35/35 [==============================] - 3s 79ms/step - loss: 4.0411e-06 - mse: 4.0411e-06 - val_loss: 0.0224 - val_mse: 0.0224
# Epoch 56/100
# 35/35 [==============================] - 3s 82ms/step - loss: 4.8426e-06 - mse: 4.8426e-06 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 57/100
# 35/35 [==============================] - 3s 80ms/step - loss: 5.2846e-06 - mse: 5.2846e-06 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 00057: early stopping

# %%
plt.figure(figsize = (15, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('LSTM Model Loss')
plt.ylabel('Loss')
plt.xlabel("Epochs")
plt.legend(['loss', 'val_loss'], loc='upper right')
plt.show()

# %%
##Predict
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)


# Invert transformation to get stock prices
train_pred = sc.inverse_transform(train_pred)
test_pred = sc.inverse_transform(test_pred)

## Observed v. Predicted Results
# Shift train prediction for plotting
train_pred_plot = np.empty_like(df)
train_pred_plot[:, :] = np.nan
train_pred_plot[time_step: len(train_pred) + time_step, :] = train_pred

# Shift test prediction for plotting
test_pred_plot = np.empty_like(df)
test_pred_plot[:, :] = np.nan
test_pred_plot[len(train_pred) + (time_step * 2) + 1: len(df) -1, :] = test_pred

plt.figure(figsize = (15, 10))
plt.plot(sc.inverse_transform(df), color = 'gray', linewidth = 1, label = 'Actual')
plt.plot(train_pred_plot, linewidth = 1, color = 'red', label = 'Train Predict')
plt.plot(test_pred_plot, linewidth = 1, color = 'green', label = 'Test Predict')
plt.legend()
plt.xlabel('Time')
plt.ylabel('TSLA Stock Price (USD)')
plt.title('TSLA Stock Price Prediction, LSTM')
plt.show()
